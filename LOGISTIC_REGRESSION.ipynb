# %%
import pandas as pd
import numpy as  np
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\pc\OneDrive\one drive\OneDrive\Documents\dataset_models\insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt=sns.scatterplot(x=df.age,y=df.bought_insurance,data=df,color='red',marker='*')
plt
# Out:
# <Axes: xlabel='age', ylabel='bought_insurance'>

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(df[['age']],df.bought_insurance,test_size=0.1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
df.shape
# Out:
# (27, 2)

# %%
lr.score(X_test,Y_test)
# Out:
# 0.6666666666666666

# %%
lr.predict_proba(X_test)
# Out:
# array([[0.53738192, 0.46261808],
#        [0.10101746, 0.89898254],
#        [0.34778602, 0.65221398]])

# %%
lr.predict([[19]])
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import accuracy_score

# %%
pr=precision_score(Y_test,y_pred)
rc=recall_score(Y_test,y_pred)
f1=f1_score(Y_test,y_pred)
ac=accuracy_score(Y_test,y_pred)

# %%
print(pr)
print(rc)
print(f1)
print(ac)
# Out:
# 1.0
# 0.6666666666666666
# 0.8
# 0.6666666666666666
